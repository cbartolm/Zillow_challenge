# %% [markdown]
# # Web Scraping for Extra information

# %%
import pandas as pd

# %%
data_set = pd.read_csv("Data/cleaned_data_R.csv")
# Out:
# /home/bcasares/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# data_set_copy = data_set.loc[1:3,:].copy(deep=True)

# %%
data_set_copy = data_set.copy(deep=True)

# %%
data_set_copy = data_set_copy.iloc[0:2,:]

# %%
# data_set_copy

# %%
new_df = pd.DataFrame()
for i, row in data_set_copy.iterrows():
    try:
        url_string = 'https://www.ffiec.gov/census/report.aspx?\
year=2016&county={county}&tract={number}&state=06&report=demographic'\
        .format(county= str(row.tract_county)[1:], number = row.tract_number)
        aaron_genius = pd.read_html(url_string, attrs = {"id":"Report1_dgReportDemographic"}, header=0)[0]
#         display(aaron_genius)
        new_df = pd.concat([new_df, aaron_genius])
    except:
        print(i)
        new_df = pd.concat([new_df, aaron_genius])

# %%
new_df = new_df.set_index(data_set_copy.index)
final_df = pd.concat([data_set_copy, new_df], axis=1)

# %%
final_df
# Out:
#    Unnamed: 0  logerror bathroomcnt bedroomcnt buildingqualitytypeid  \
# 0           1   -0.0274           2          3                     7
# 1           2   -0.0274           2          4                  None
#
#    calculatedfinishedsquarefeet heatingorsystemtypeid    latitude  \
# 0                        1836.0                     2  34237258.0
# 1                        1199.0                  None  34166196.0
#
#      longitude  lotsizesquarefeet          ...            \
# 0 -118490025.0             9676.0          ...
# 1 -119169155.0             6000.0          ...
#
#   Distressed or Under -served Tract  Tract Median Family Income %  \
# 0                                No                        133.71
# 1                                No                         60.16
#
#   2016 FFIEC Est. MSA/MD non-MSA/MD Median Family Income  \
# 0                                            $62,400
# 1                                            $88,300
#
# ...

# %%
data_set_copy.append(new_df)
# Out:
# /home/bcasares/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#    1- to 4- Family Units 2010 Tract Median Family Income  \
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 0                 1324.0                         $50,759
# 0                 1336.0                         $72,473
# 0                 1170.0                        $107,569
#
#   2016 Est. Tract Median Family Income  \
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 0                              $53,121
# ...

# %%
aaron_genius = pd.read_html(url_string, attrs = {"id":"Report1_dgReportDemographic"}, header=0)[0]

# %%
aaron_genius[0]
# Out:
#   Tract Income Level Distressed or Under -served Tract  \
# 0              Upper                                No
#
#    Tract Median Family Income %  \
# 0                        234.73
#
#   2016 FFIEC Est. MSA/MD non-MSA/MD Median Family Income  \
# 0                                            $62,400
#
#   2016 Est. Tract Median Family Income 2010 Tract Median Family Income  \
# 0                             $146,472                        $144,647
#
#    Tract Population  Tract Minority %  Minority Population  \
# 0              6740             18.25                 1230
#
#    Owner Occupied Units  1- to 4- Family Units
# 0                  2160                   2422

# %%
# data_set

# %%
f4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'], 'D': ['D2', 'D3', 'D6', 'D7'], 'F': ['F2', 'F3', 'F6', 'F7']})

# %%
f5 = f4.apply(lambda x: x)
pd.concat([f4, f4], axis=1)
# Out:
#     B   D   F   B   D   F
# 0  B2  D2  F2  B2  D2  F2
# 1  B3  D3  F3  B3  D3  F3
# 2  B6  D6  F6  B6  D6  F6
# 3  B7  D7  F7  B7  D7  F7
